# %% [markdown]
# # 1. urlretrieve
#
# 이미지 ,페이지소스 저장

# %%
import urllib.request as req

# 파일 URL
img_url = 'https://c2.staticflickr.com/8/7058/6895007878_6930f04b59_b.jpg'
html = 'https://google.com'

#다운받을 경로
save_path1 = 'C:/tiger.jpg'
save_path2 = 'C:/index.html'

#예외처리
try:
    file1, header1 = req.urlretrieve(img_url, save_path1)
    file2, header2 = req.urlretrieve(html, save_path2)
    
except Exception as e:
    print('Download failed')
    print(e)
else:
    #Header 정보 출력
    print(header1)
    print(header2)
    
    #다운로드 파일 정보
    print('Filename1 {}'.format(file1))
    print('Filename2 {}'.format(file2))
    
    #성공
    print('Download Succeed')
# Out:
# Content-Type: image/jpeg
# Content-Length: 164304
# Connection: close
# Date: Thu, 06 Feb 2020 12:30:16 GMT
# Edge-Control: public, max-age=31536000
# Surrogate-Control: public, max-age=31536000
# Cache-Control: public, max-age=31536000
# Expires: Fri, 05 Feb 2021 12:30:16 GMT
# ImageWidth: 1024
# ImageHeight: 683
# Content-MD5: ILWqPxrBNZMn4x2YCcDF6g==
# ETag: "20b5aa3f1ac1359327e31d9809c0c5ea"
# Last-Modified: Sat, 23 Feb 2019 07:23:06 GMT
# Streaming: false
# OriginType: D
# Server: Jubilee
# Quote: "I'm not a kid anymore, I'm one of you, one of the X-Men. It means more to me than anything in the world."
# Access-Control-Allow-Origin: *
# Access-Control-Allow-Methods: GET, OPTIONS
# Powered-By: Mutation/1.0
# Hiring: Change the world of photography with us. https://www.flickr.com/jobs/
# OurValues: Deliver Awesome (#3 of 5)
# X-Request-Id: 7ec086bb
# X-Frame-Options: DENY
# P3P: CP="This is not a P3P policy. We respect your privacy."
# X-Env: a=live, b=jubilee, c=0088f9d9, e=9d61589, f=0cc8f66
# X-UA-Compatible: IE=edge
# X-TTFB: 0.1318
# X-TTDB-L: 164304
# MiB: 2
# X-Cache: Hit from cloudfront
# Via: 1.1 4f50ba108cfdf1c401c86d18cfe7a64d.cloudfront.net (CloudFront)
# X-Amz-Cf-Pop: ICN50
# X-Amz-Cf-Id: flH_DUD-eCMMLait6MCEL7zpsVgzqej9ql4KlsnWUAIjiK1Fw7k3Jw==
# Age: 295
#
#
# Content-Type: image/jpeg
# Content-Length: 164304
# Connection: close
# Date: Thu, 06 Feb 2020 12:30:16 GMT
# Edge-Control: public, max-age=31536000
# Surrogate-Control: public, max-age=31536000
# Cache-Control: public, max-age=31536000
# Expires: Fri, 05 Feb 2021 12:30:16 GMT
# ImageWidth: 1024
# ImageHeight: 683
# Content-MD5: ILWqPxrBNZMn4x2YCcDF6g==
# ETag: "20b5aa3f1ac1359327e31d9809c0c5ea"
# Last-Modified: Sat, 23 Feb 2019 07:23:06 GMT
# Streaming: false
# OriginType: D
# Server: Jubilee
# Quote: "I'm not a kid anymore, I'm one of you, one of the X-Men. It means more to me than anything in the world."
# Access-Control-Allow-Origin: *
# Access-Control-Allow-Methods: GET, OPTIONS
# Powered-By: Mutation/1.0
# Hiring: Change the world of photography with us. https://www.flickr.com/jobs/
# OurValues: Deliver Awesome (#3 of 5)
# X-Request-Id: 7ec086bb
# X-Frame-Options: DENY
# P3P: CP="This is not a P3P policy. We respect your privacy."
# X-Env: a=live, b=jubilee, c=0088f9d9, e=9d61589, f=0cc8f66
# X-UA-Compatible: IE=edge
# X-TTFB: 0.1318
# X-TTDB-L: 164304
# MiB: 2
# X-Cache: Hit from cloudfront
# Via: 1.1 1787e729a1c3fb1d4583d4cb9052972b.cloudfront.net (CloudFront)
# X-Amz-Cf-Pop: ICN50
# X-Amz-Cf-Id: rf15oD9xs0qo6c9Mo4obp6h-4PJiQBlB3PckxXQg5nhg_I3-VouUSg==
# Age: 296
#
#
# Filename1 C:/tiger.jpg
# Filename2 C:/index.html
# Download Succeed

# %% [markdown]
# # 2. urlopen

# %%
import urllib.request as req
from urllib.error import URLError,HTTPError#예외처리 중요 -> 코드의 퀄리티 완성도를 높인다.

#다운로드 경로 및 파일명
path_list = ['C:/tiger.jpg','C:/index.html']

#다운로드 리소스 url
target_url = ['https://upload.wikimedia.org/wikipedia/commons/thumb/7/73/Lion_waiting_in_Namibia.jpg/1200px-Lion_waiting_in_Namibia.jpg','http://google.com']

for i,url in enumerate(target_url):
    
    #예외처리
    try:
        #웹 수신 정보 읽기
        response = req.urlopen(url)
        
        #수신내용
        contents = response.read() #메서드 read
        
        print("-----------------------------------------------------")
        
        #상태 정보 중간 출력
        print('Header Info-{} : {}'.format(i, response.info())) #메서드 info
        print('HTTP Status Code: {}'.format(response.getcode())) #메서드 getcode
        print("-----------------------------------------------------")
        
        with open(path_list[i],'wb') as c:
            c.write(contents)
        
        
    except HTTPError as e:
        print('Download failed')
        print('HTTPError code: ', e.code)
    except URLError as e:
        print('Download failed')
        print('URL Error Reason : ', e.reason)
        
    #성공
    else:
        print()
        print('Download Succeed.')
# Out:
# -----------------------------------------------------
# Header Info-0 : Date: Sat, 08 Feb 2020 06:12:31 GMT
# Etag: 2e2a292c0c641da73d26ab1aa102ab63
# Server: ATS/8.0.5
# X-ATS-Timestamp: 1581142351
# Content-Type: image/jpeg
# Content-Length: 229952
# X-Object-Meta-Sha1Base36: jb1b320jtx9u4a4zdqwto8kpd57gxs5
# Last-Modified: Tue, 23 Feb 2016 20:08:29 GMT
# X-Timestamp: 1456258108.79035
# X-Trans-Id: tx08d3e1e800454b4ca97b8-005e1ec599
# X-Varnish: 275999407 193786211
# Age: 21562
# X-Cache: cp5005 hit, cp5002 hit/20
# X-Cache-Status: hit-front
# Server-Timing: cache;desc="hit-front"
# Strict-Transport-Security: max-age=106384710; includeSubDomains; preload
# X-Client-IP: 58.141.62.206
# Access-Control-Allow-Origin: *
# Access-Control-Expose-Headers: Age, Date, Content-Length, Content-Range, X-Content-Duration, X-Cache, X-Varnish
# Timing-Allow-Origin: *
# Accept-Ranges: bytes
# Connection: close
#
#
# HTTP Status Code: 200
# -----------------------------------------------------
#
# Download Succeed.
# -----------------------------------------------------
# Header Info-1 : Date: Sat, 08 Feb 2020 12:11:54 GMT
# Expires: -1
# Cache-Control: private, max-age=0
# Content-Type: text/html; charset=ISO-8859-1
# P3P: CP="This is not a P3P policy! See g.co/p3phelp for more info."
# Server: gws
# X-XSS-Protection: 0
# X-Frame-Options: SAMEORIGIN
# Set-Cookie: 1P_JAR=2020-02-08-12; expires=Mon, 09-Mar-2020 12:11:54 GMT; path=/; domain=.google.com; Secure
# Set-Cookie: NID=197=oe1cYJY3ZMwLbE4ML57j0rpJFixhcLPbzR3RmzWnfzTncesW7z5Pkhbr7QF4wjuU9buk4-HRr_Y80s4pJ0118n0QJIDI9pxD-e2THlyn2RUmlNIn2-Zbi2dyxBI65c8avXqk-HQcJxSLhWaUBNvGcoWrA-roCaPrWLL3tWmPcCs; expires=Sun, 09-Aug-2020 12:11:54 GMT; path=/; domain=.google.com; HttpOnly
# Accept-Ranges: none
# Vary: Accept-Encoding
# Connection: close
#
#
# HTTP Status Code: 200
# -----------------------------------------------------
#
# Download Succeed.

# %% [markdown]
# # 3. 네이버 메인페이지 기사 링크 크롤링
#
# copy selector가 만능은 아니다. 하나의 값이 아닌 전체를 가져올 때는 보통 직접 "아이디,클래스,태그,속성"를 검색해보고 접근하여 추출한다.
#
# lxml (lxml.html.fromstring)<br>
# requests

# %%
import lxml.html
import requests


def main():
    """
    네이버 메인뉴스 스탠드 스크래핑 메인함수
    """
    # 스크래핑 대상 URL
    response = requests.get("https://www.naver.com") # get방식
    
    #신문사 링크 리스트 획득
    urls = scrape_news_list_page(response)
    
    #결과출력
    for url in urls:
        #url출력
        print(url)
        #파일쓰기
        #생략
        
        
def scrape_news_list_page(response):
    #URL리스트 선언
    urls = []
    
    #태그 정보 문자열 저장
    root = lxml.html.fromstring(response.content)
    
    for  a in root.cssselect('.api_list .api_item a.api_link'):
        #링크
        url = a.get('href')
        urls.append(url)
    
    return urls
    
    
#스크래핑 시작
if __name__ == "__main__":
    main()
# Out:
# http://newsstand.naver.com/?list=ct1&pcode=327
# http://newsstand.naver.com/?list=ct1&pcode=016
# http://newsstand.naver.com/?list=ct1&pcode=214
# http://newsstand.naver.com/?list=ct1&pcode=241
# http://newsstand.naver.com/?list=ct1&pcode=326
# http://newsstand.naver.com/?list=ct1&pcode=079
# http://newsstand.naver.com/?list=ct1&pcode=029
# http://newsstand.naver.com/?list=ct1&pcode=047
# http://newsstand.naver.com/?list=ct1&pcode=055
# http://newsstand.naver.com/?list=ct1&pcode=014
# http://newsstand.naver.com/?list=ct1&pcode=018
# http://newsstand.naver.com/?list=ct1&pcode=005
# http://newsstand.naver.com/?list=ct7&pcode=384
# http://newsstand.naver.com/?list=ct7&pcode=094
# http://newsstand.naver.com/?list=ct2&pcode=013
# http://newsstand.naver.com/?list=ct2&pcode=939
# http://newsstand.naver.com/?list=ct3&pcode=340
# http://newsstand.naver.com/?list=ct2&pcode=963

# %% [markdown]
# # 4. 완성된 스크래핑 코드 작성
#
# * Session 이용해서 로그인 정보를 얻을 수 있다. 연결의 흐름을 유지하여 일정된 서비스를 제공할 수 있다. <br>
# ex) 로그인 활성화 상태 <- Session 정보 사용
# <br>
#
# * xpath로 값 찾기 <br><br>
#
# * 딕셔너리 형태 출력

# %%
from lxml.html import fromstring, tostring
import requests


def main():
    """
    네이버 메인뉴스 스탠드 스크래핑 메인함수
    """
    #세션 사용
    session = requests.Session()
    
    # 스크래핑 대상 URL
    response = requests.get("https://www.naver.com") # get방식
    
    #신문사 링크 딕셔너리 획득
    urls = scrape_news_list_page(response)
    
    #결과출력
    for name, url in urls.items():
        
        #url출력
        print(name, url)
        
        #파일쓰기
        #생략
        
        
def scrape_news_list_page(response):
    
    #URL리스트 선언
    urls = {}
    
    #태그 정보 문자열 저장
    root = fromstring(response.content)
    
    for  a in root.xpath('//ul[@class="api_list"]/li[@class="api_item"]/a[@class="api_link"]'):
        
        #a 구조확인
#         print(a)
        
        # a의 문자열 출력
#         print(tostring(a,pretty_print=True))
    
        name, url = extract_contents(a)
        # 딕셔너리 삽입
        urls[name] =  url
        
    return urls


def extract_contents(dom):
    #링크주소
    link = dom.get('href')
    
    #신문사명
    name = dom.xpath('./img')[0].get('alt') #xpath('/img')
    return  name , link

    
#스크래핑 시작
if __name__ == "__main__":
    main()
# Out:
# 서울신문 http://newsstand.naver.com/?list=ct1&pcode=081
# 문화일보 http://newsstand.naver.com/?list=ct1&pcode=021
# JTBC http://newsstand.naver.com/?list=ct1&pcode=904
# 시사인 http://newsstand.naver.com/?list=ct1&pcode=308
# YTN http://newsstand.naver.com/?list=ct1&pcode=052
# 머니투데이 http://newsstand.naver.com/?list=ct1&pcode=008
# 서울경제 http://newsstand.naver.com/?list=ct1&pcode=011
# 한국경제 http://newsstand.naver.com/?list=ct1&pcode=015
# 지지통신 http://newsstand.naver.com/?list=ct1&pcode=376
# 매일경제 http://newsstand.naver.com/?list=ct1&pcode=009
# 연합뉴스TV http://newsstand.naver.com/?list=ct1&pcode=422
# 블로터 http://newsstand.naver.com/?list=ct1&pcode=293
# CNN http://newsstand.naver.com/?list=ct3&pcode=933
# 시사오늘 http://newsstand.naver.com/?list=ct2&pcode=816
# tbs교통방송 http://newsstand.naver.com/?list=ct3&pcode=981
# TV조선 http://newsstand.naver.com/?list=ct3&pcode=902
# 조세일보 http://newsstand.naver.com/?list=ct2&pcode=123
# 에너지경제 http://newsstand.naver.com/?list=ct2&pcode=963

# %% [markdown]
# # 5. 사이트 요청 정보 확인
#
# * encar(엔카) 사이트 정보 수신
#
# * Get 파라미터 요청
#
# * 수신 데이터 디코딩(Decoding)
#
# * 요청 URL 정보분석

# %%
import urllib.request 
from urllib.parse import urlparse

# 기본 요청1(encar)
url = "http://www.encar.com"

mem = urllib.request.urlopen(url)

# 여러정보
print('type : {}'.format(type(mem)))
print('getrul: {}'.format(mem.geturl()))  #자동으로 리다이렉트된 수신 사이트주소를 리턴
print('status: {}'.format(mem.status)) # or getcode
print('headers: {}'.format(mem.getheaders())) #수신된 헤더 정보
print('getcode: {}'.format(mem.getcode())) # or tatus
print('read: {}'.format(mem.read(100).decode('utf-8'))) # 바이트수 지정 ,바이트수가 너무크면 에러가 날 수 있다.
print('parse: {}'.format(urlparse('http://www.encar.co.kr?id=test&pw=1111'))) #전체정보
print('parse: {}'.format(urlparse('http://www.encar.co.kr?id=test&pw=1111').query)) # parse를 사용하여 쿼리정보만 확인

#get방식은 주요정보가 노출이 되기때문에 공개적인 서비스(ex.신문사)에서 사용된다.
#중요하거나 원문 데이터는 post방식을 사용
# 위의 정보를 사용하여 예외처리를 할 수있기때문에 urllib를 사용
# Out:
# type : <class 'http.client.HTTPResponse'>
# getrul: http://www.encar.com/index.do
# status: 200
# headers: [('Date', 'Thu, 06 Feb 2020 20:36:48 GMT'), ('Set-Cookie', 'WMONID=mfIrQvkDyMr; Expires=Sat, 06-Feb-2021 5:36:48 GMT; Path=/'), ('Content-Type', 'text/html; charset=EUC-KR'), ('Connection', 'close'), ('Content-Language', 'ko-KR'), ('Set-Cookie', 'JSESSIONID=J09MXePp7RDe3fQ0kBBERh1xPOQgeaAuh9org01aq5YkfZB14LOdGaF8PlzDaLtK.encarwas1_servlet_engine3;Path=/'), ('P3P', "CP='CAO PSA CONi OTR OUR DEM ONL'"), ('X-UA-Compatible', 'IE=Edge'), ('Transfer-Encoding', 'chunked')]
# getcode: 200
# read:
#
#
#
#
#
#
#
#
#
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <meta charset="euc-kr">
#
#
#
#
# <tit
# parse: ParseResult(scheme='http', netloc='www.encar.co.kr', path='', params='', query='id=test&pw=1111', fragment='')
# parse: id=test&pw=1111
# before param : {'format': 'json'}
# after param : {'format': 'json'}

# %%
# 기본 요청2(ipifi)
API = 'https://api.ipify.org'

# Get 방식 Parameter
values = {
    'format' : 'json'
#     'format' : 'jsonP'
#     'format' : 'text'
}

print('before param : {}'.format(values))
params = urllib.parse.urlencode(values)
print('after param : {}'.format(values))


# 요청 URL 생성
URL = API + "?" + params   #수신요청한 나의 아이피주소


# 수신 데이터 읽기
data = urllib.request.urlopen(URL).read()

# 수신데이터 디코딩
text = data.decode('UTF-8') # python3버젼은 기본적으로 utf-8 이기 떄문.
print('response: {}'.format(text)) # 나의 아이피가 서버에서 내려준 정보를 수신했다는 것을 나타냄
# Out:
# before param : {'format': 'json'}
# after param : {'format': 'json'}
# https://api.ipify.org?format=json
# response: {"ip":"58.141.62.196"}

# %% [markdown]
# # 6. 행정안전부 사이트 RSS 데이터 수신
#
# * RSS란?
#
# https://www.mois.go.kr/gpms/view/jsp/rss/rss.jsp?ctxCd=1001 <br>ctxCd=1001<br>
# https://www.mois.go.kr/gpms/view/jsp/rss/rss.jsp?ctxCd=1013 <br>ctxCd=1013<br>
# .
# .
#
#
# * 반복문을 활용한 연속 요청
#
# * 요청 URL 정보 분석
#
# * 수신 XML 데이터 확인

# %%
import urllib.request
import urllib.parse

# 행정 안전부 : https://www.mois.go.kr
# 행정 안전부 RSS API URL

API = 'https://www.mois.go.kr/gpms/view/jsp/rss/rss.jsp'

params = []

for num in [1001,1012,1013]:
    
    params.append(dict(ctxCd=num))
    
# 중간 확인
print(params)


#연속해서 4회 요청
for c in params:
    
    # 파라미터 출력
    # print(c)
    
    # URL 인코딩
    params = urllib.parse.urlencode(c)  # 딕셔너리를 url 형태로 변환  { a : b }  ->  a = b
    
    #URL완성
    url = API + '?' + params
    
    # URL 출력
    print('url :',url)
    
    # 요청
    res_data = urllib.request.urlopen(url).read()
#     print(res_data)

    # 수신 후 디코딩
    contents = res_data.decode("UTF-8")
    
    # 출력
    print("*"*100)
    print("*"*100)
    print("*"*100)
    print("*"*100)
    print(contents)
# Out:
# [{'ctxCd': 1001}, {'ctxCd': 1012}, {'ctxCd': 1013}]
# url : https://www.mois.go.kr/gpms/view/jsp/rss/rss.jsp?ctxCd=1001
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# <?xml version="1.0" encoding="UTF-8" ?>
# <rss version="2.0"
#     xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#     xmlns:dc="http://purl.org/dc/elements/1.1/"
#     xmlns:taxo="http://purl.org/rss/1.0/modules/taxonomy/"
#     xmlns:activity="http://activitystrea.ms/spec/1.0/" >
# <channel>
# <title>알립니다</title>
# <link>https://www.mois.go.kr</link>
# <description></description>
# <language>ko</language>
# <pubDate>THU, 06 FEB 2020 18:24:31 KST</pubDate>
#     <item>
#             <title><![CDATA[행정안전부 국제협력분야 일반임기제 공무원 서류전형 합격자 및 면접시험 일정 공고]]></title>
#             <link><![CDATA[https://www.mois.go.kr/frt/bbs/type013/commonSelectBoardArticle.do?bbsId=BBSMSTR_000000000006&nttId=75656]]></link>
#             <description><![CDATA[
#                 행정안전부 공고 제2020-79호<br /><br /><br />행정안전부 국제협력분야 일반임기제(행정6급) 공무원 <br /><br />서류전형 합격자 및 면접시험 일정을 붙임과 같이 안내합니다.<br /><br /><br />2020년 2월 6일<br /><br />행정안전부장관
#                     ]]></description>
#             <pubDate>THU, 06 FEB 2020 18:24:31 KST</pubDate>
#             <author>인사기획관</author>
#         </item>
#     <item>
#             <title><![CDATA[[공모전] 2020년 지역주도형 청년일자리사업 개선과제 공모전]]></title>
#             <link><![CDATA[https://www.mois.go.kr/frt/bbs/type013/commonSelectBoardArticle.do?bbsId=BBSMSTR_000000000006&nttId=75631]]></link>
#             <description><![CDATA[
#                 행정안전부는 청년의 의견을 직접 수렴하여 사업을 개선함으로써 참여청년의 만족도를 더욱 제고하기 위해<br />"지역주도형 청년일자리사업 개선과제 공모전"을 개최합니다. <br />참여과정에서 경험한 애로사항을 바탕으로 이를 개선하기 위한 참신하고 실현가능한 아이디어를 제출해주시기 바랍니다.<br /> <br />  [공모전 내용] <br /><br />   ○ (공모기간) '20. 2.6.(목) ~ '20. 3. 6.(금) (30일간)<br /><br />   ○ (응모자격) 지역주도형 청년일자리사업에 참여한 경험이 있는 청년, 사업장, 지자체 등  (* 참여기준 : '18.7.1.~ 현재까지 참여)<br />  <br />   ○ (공모주제) "청년이 직접 바꾸는 지역주도형 청년일자리사업"<br />   <br />    - 지역정착, 창업, 민간취업연계형 3대 유형별로 사업에 참여하며 겪은 애로사항과 이를 개선하기 위한 아이디어 등<br /><br />   ○ (공모방법) 첨부파일의 "(작성서식) 개선과제 제안서"를 작성 후, 이메일(regionaljobs@korea.kr)로 제출  (* 분량제한 없음) <br /> <br />   ○ (당선자발표) '20. 3. 18.(수)  (* 홈페이지 게재 및 당선자 개별통보 예정)  <br /><br />   ○ (시상내역) 최우수 3명(각 30만원), 우수 6명(각 20만원), 장려 14명(각 10만원) (* 선정규모는 조정가능)<br />  <br />    - 최우수, 우수작은 각 유형별로 선정하고, 장려상의 경우 유형공통으로 선정<br /><br />    <br />※ 자세한 사항은 첨부파일의 "공고문"을 참고하시기 바랍니다. (문의: 지역일자리경제과 박지연 044-205-3914)
#                     ]]></description>
#             <pubDate>WED, 05 FEB 2020 14:24:31 KST</pubDate>
#             <author>지역일자리경제과</author>
#         </item>
#     <item>
#             <title><![CDATA[제4기 유ㆍ도선 국민안전현장관찰단 공개 모집(2.3 ~ 2.28)]]></title>
#             <link><![CDATA[https://www.mois.go.kr/frt/bbs/type013/commonSelectBoardArticle.do?bbsId=BBSMSTR_000000000006&nttId=75548]]></link>
#             <description><![CDATA[
#                 국민 관점의 현장중심 안전관리 강화를 위한 "제4기 유ㆍ도선 국민안전현장관찰단"을 공개 모집합니다.<br /><br />○ 모집기간 : '20.2.03.09:00 ~ '20.2.28.18:00<br /><br />○ 모집인원 : 총 25명 내외(권역별 5명)  *수도권, 강원권, 충청권, 영남권, 호남권(제주포함)<br /><br />○ 신청자격 : 전국 일반 국민(만 19세 이상, 연령ㆍ성별ㆍ직업 등 안배)<br /><br />○ 위촉기간 : 2020년 4월 ~ 2021년 11월(2년간)<br /><br />○ 주요활동 <br /> - 유ㆍ도선 개선제도 및 안전정책 현장 이행실태 모니터링(점검)<br /> - "유ㆍ도선 안전혁신 T/F회의" 참여를 통한 국민 관점의 의견 제시<br /> - 현장점검 참여, 국민 시각의 정책ㆍ제도 자문, 홍보, 위해요소 제보 등<br /><br /> ※ 관찰활동 수당지급 : 10만원(운영예산 한도 내에서 집행)<br /><br /><br />자세한 내용(응모 및 접수요령 등)은 첨부파일을 참조하시기 바랍니다.
#                     ]]></description>
#             <pubDate>FRI, 31 JAN 2020 09:33:12 KST</pubDate>
#             <author>안전제도과</author>
#         </item>
#     </channel>
# </rss>
#
#
# url : https://www.mois.go.kr/gpms/view/jsp/rss/rss.jsp?ctxCd=1012
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# <?xml version="1.0" encoding="UTF-8" ?>
# <rss version="2.0"
#     xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#     xmlns:dc="http://purl.org/dc/elements/1.1/"
#     xmlns:taxo="http://purl.org/rss/1.0/modules/taxonomy/"
#     xmlns:activity="http://activitystrea.ms/spec/1.0/" >
# <channel>
# <title>보도자료</title>
# <link>https://www.mois.go.kr</link>
# <description></description>
# <language>ko</language>
# <pubDate>THU, 06 FEB 2020 14:10:00 KST</pubDate>
#     <item>
#             <title><![CDATA[정부, 신종 코로나바이러스 긴급대응연구 추진한다]]></title>
#             <link><![CDATA[https://www.mois.go.kr/frt/bbs/type010/commonSelectBoardArticle.do?bbsId=BBSMSTR_000000000008&nttId=75654]]></link>
#             <description><![CDATA[
#                 1월 20일 우리나라 최초 확진자 발생 이후, 지속적으로 확진자가 증가하고 있는 요즈음, 신종 코로나바이러스 감염증 확산 대응에 총력을 기울이기 위해 관계부처가 적극 나선다.<br /><br />자세한 내용은 첨부를 확인하시기 바랍니다. <br /> <br />* 담당 : 재난안전연구개발과 박승기 사무관(044-205-6233)
#                     ]]></description>
#             <pubDate>THU, 06 FEB 2020 14:10:00 KST</pubDate>
#             <author>홍보담당관</author>
#         </item>
#     <item>
#             <title><![CDATA[행안부, 오는 9월 580여개 공공기관 대상 정보공개 운영 수준 평가]]></title>
#             <link><![CDATA[https://www.mois.go.kr/frt/bbs/type010/commonSelectBoardArticle.do?bbsId=BBSMSTR_000000000008&nttId=75653]]></link>
#             <description><![CDATA[
#                 행정안전부(장관 진영)는, 올해 580여개 공공기관을 대상으로 정보공개 운영 수준을 평가합니다. <br /><br />자세한 내용은 첨부를 확인하시기 바랍니다. <br /> <br />* 담당 : 정보공개정책과 채희선(044-205-2270)
#                     ]]></description>
#             <pubDate>THU, 06 FEB 2020 12:00:00 KST</pubDate>
#             <author>홍보담당관</author>
#         </item>
#     <item>
#             <title><![CDATA[지방공공기관 임원 채용비위시 인적사항 등 공개된다.]]></title>
#             <link><![CDATA[https://www.mois.go.kr/frt/bbs/type010/commonSelectBoardArticle.do?bbsId=BBSMSTR_000000000008&nttId=75652]]></link>
#             <description><![CDATA[
#                 행정안전부(장관 진영)는 2.7일 지방공공기관 지방공기업(자치단체가 직접 설치 경영하는 지방직영기업 및 자치단체가 지분 50% 이상을 출자하여 설립한 지방공사‧공단)과 지방출자출연기관(자치단체가 10% 이상 출자한 출자기관 및 자치단체 출연기관으로 지방출자‧출연법 제5조에 따라 지정‧고시된 기관) 모두를 의미<br /> 채용비리 근절 등을 위한 「지방공기업법」 및 「지방자치단체 출자‧출연 기관의 운영에 관한 법률」(이하 ‘「지방출자출연법」’) 시행령 개정안을 입법예고(2.7~3.18)합니다.<br /><br />자세한 내용은 첨부를 확인하시기 바랍니다. <br /> <br />* 담당 : 공기업정책과 천혜원(044-205-3962), 공기업지원과 한수덕(044-205-3990)
#                     ]]></description>
#             <pubDate>THU, 06 FEB 2020 12:00:00 KST</pubDate>
#             <author>홍보담당관</author>
#         </item>
#     <item>
#             <title><![CDATA[공공데이터, 기업 성장에 지속적으로 기여]]></title>
#             <link><![CDATA[https://www.mois.go.kr/frt/bbs/type010/commonSelectBoardArticle.do?bbsId=BBSMSTR_000000000008&nttId=75651]]></link>
#             <description><![CDATA[
#                 공공기관에서 개방하는 공공데이터가 기업 매출 증가, 비즈니스 혁신 및 고용확대에 지속적으로 기여하고 있는 것으로 조사됐습니다.<br /><br />자세한 내용은 첨부를 확인하시기 바랍니다. <br /> <br />* 담당 : 공공데이터정책과 김강욱(044-205-2293)
#                     ]]></description>
#             <pubDate>THU, 06 FEB 2020 12:00:00 KST</pubDate>
#             <author>홍보담당관</author>
#         </item>
#     <item>
#             <title><![CDATA[행안부, 청년 의견 모아 청년일자리 사업 개선방안 마련]]></title>
#             <link><![CDATA[https://www.mois.go.kr/frt/bbs/type010/commonSelectBoardArticle.do?bbsId=BBSMSTR_000000000008&nttId=75650]]></link>
#             <description><![CDATA[
#                 행정안전부(장관 진영)는 2월 6일부터 3월 6일까지『지역주도형 청년일자리 사업』개선과제 공모전을 실시합니다.<br /><br />자세한 내용은 첨부를 확인하시기 바랍니다. <br /> <br />* 담당 : 지역일자리경제과 박지연(044-205-3914)
#                     ]]></description>
#             <pubDate>THU, 06 FEB 2020 07:30:00 KST</pubDate>
#             <author>홍보담당관</author>
#         </item>
#     <item>
#             <title><![CDATA[재해예방사업 10% 증액, 신속 정비를 위해 조기 발주]]></title>
#             <link><![CDATA[https://www.mois.go.kr/frt/bbs/type010/commonSelectBoardArticle.do?bbsId=BBSMSTR_000000000008&nttId=75617]]></link>
#             <description><![CDATA[
#                 행정안전부(장관 진영)는 예방중심 재난관리를 위해 작년대비 약 10% 증액된 1조 144억의 예산(국비 5,072억, 지방비 5,072억)을 확보하고 전국 572개 지구에서 재해예방사업을 조기에 추진할 계획이라고 밝혔습니다.<br /><br />자세한 내용은 첨부를 확인하시기 바랍니다. <br /> <br />* 담당 : 재난경감과 정인성(044-205-5151)
#                     ]]></description>
#             <pubDate>WED, 05 FEB 2020 12:00:00 KST</pubDate>
#             <author>재난경감과</author>
#         </item>
#     <item>
#             <title><![CDATA[사라져가는 디지털 국가정보를 지켜라]]></title>
#             <link><![CDATA[https://www.mois.go.kr/frt/bbs/type010/commonSelectBoardArticle.do?bbsId=BBSMSTR_000000000008&nttId=75616]]></link>
#             <description><![CDATA[
#                 정부가 사라져가는 디지털정보의 효율적 관리를 위해 국가 중요 정보자원 보존체계를 구축한다. <br /><br />자세한 내용은 첨부를 확인하시기 바랍니다. <br /> <br />* 담당 : 정보자원보존기획단 양은성(044-205-2892)
#                     ]]></description>
#             <pubDate>WED, 05 FEB 2020 12:00:00 KST</pubDate>
#             <author>정보자원보존기획단</author>
#         </item>
#     <item>
#             <title><![CDATA[신종 코로나 바이러스 피해자에 대한 지방세 지원]]></title>
#             <link><![CDATA[https://www.mois.go.kr/frt/bbs/type010/commonSelectBoardArticle.do?bbsId=BBSMSTR_000000000008&nttId=75640]]></link>
#             <description><![CDATA[
#                 행정안전부(장관 진영)는 신종 코로나 바이러스로 인하여 어려움을 겪는 납세자를 지원하기 위해 기한연장, 징수유예, 세무조사 유예 등 지방세 지원을 실시한다고 밝혔습니다. <br /><br />자세한 내용은 첨부를 확인하시기 바랍니다. <br /> <br />* 담당 : 지방세정책과 한송희(044-205-3803)
#                     ]]></description>
#             <pubDate>WED, 05 FEB 2020 11:00:00 KST</pubDate>
#             <author>지방세정책과</author>
#         </item>
#     <item>
#             <title><![CDATA[공공기관 PC, MS윈도우 대신 개방형OS 사용한다]]></title>
#             <link><![CDATA[https://www.mois.go.kr/frt/bbs/type010/commonSelectBoardArticle.do?bbsId=BBSMSTR_000000000008&nttId=75607]]></link>
#             <description><![CDATA[
#                 올해 말부터 행정기관이나 공공기관에서 사용하는 컴퓨터 운영프로그램이 마이크로소프트사(MS)의 윈도우에서 개방형 운영체제(OS : Operating System)로 교체됩니다.<br /><br />자세한 내용은 첨부를 확인하시기 바랍니다. <br /> <br />* 담당 : 정보자원정책과 김경직(044-205-2812)
#                     ]]></description>
#             <pubDate>TUE, 04 FEB 2020 15:00:00 KST</pubDate>
#             <author>정보자원정책과</author>
#         </item>
#     <item>
#             <title><![CDATA[‘안전실천 15초 영상 공모전’당선작 발표]]></title>
#             <link><![CDATA[https://www.mois.go.kr/frt/bbs/type010/commonSelectBoardArticle.do?bbsId=BBSMSTR_000000000008&nttId=75613]]></link>
#             <description><![CDATA[
#                 행정안전부(장관 진영)는 생활 속 안전사고 예방 및 안전수칙 실천의 중요성에 대해 국민이 제안하는「안전실천 15초 영상 공모전」을 실시하고 우수 작품을 선정했다.<br /><br />자세한 내용은 첨부를 확인하시기 바랍니다. <br /> <br />* 담당 : 안전문화교육과 김윤희(044-205-4274)
#                     ]]></description>
#             <pubDate>TUE, 04 FEB 2020 14:00:00 KST</pubDate>
#             <author>안전문화교육과</author>
#         </item>
#     <item>
#             <title><![CDATA[신종 코로나바이러스 감염증 긴급대책 특교세 48억 원 지원]]></title>
#             <link><![CDATA[https://www.mois.go.kr/frt/bbs/type010/commonSelectBoardArticle.do?bbsId=BBSMSTR_000000000008&nttId=75602]]></link>
#             <description><![CDATA[
#                 행정안전부(장관 진영)는 신종 코로나바이러스 감염증 확산 방지를 위하여 재난안전 특별교부세 48억 원을 긴급 지원한다고 밝혔습니다.<br /><br />자세한 내용은 첨부를 확인하시기 바랍니다. <br /> <br />* 담당 : 재난관리정책과 이정훈(044-205-5126)
#                     ]]></description>
#             <pubDate>MON, 03 FEB 2020 17:10:00 KST</pubDate>
#             <author>재난관리정책과</author>
#         </item>
#     <item>
#             <title><![CDATA[행안부,‘생활속 불공정 행위’척결 위해 올해 감찰 강화]]></title>
#             <link><![CDATA[https://www.mois.go.kr/frt/bbs/type010/commonSelectBoardArticle.do?bbsId=BBSMSTR_000000000008&nttId=75578]]></link>
#             <description><![CDATA[
#                 행정안전부(장관 진영)는 올해 감찰 중점 방향을 ‘생활속 불공정 행위 근절’로 설정하고, 이에 대한 감찰을 강화해 나가겠다고 3일 밝혔습니다.<br /><br />자세한 내용은 첨부를 확인하시기 바랍니다. <br /> <br />* 담당 : 복무감찰담당관 양현우(044-205-1172)
#                     ]]></description>
#             <pubDate>MON, 03 FEB 2020 12:00:00 KST</pubDate>
#             <author>복무감찰담당관</author>
#         </item>
#     <item>
#             <title><![CDATA[호텔, 연수원 등 민간시설도 이재민 임시주거시설로 사용 가능해져]]></title>
#             <link><![CDATA[https://www.mois.go.kr/frt/bbs/type010/commonSelectBoardArticle.do?bbsId=BBSMSTR_000000000008&nttId=75577]]></link>
#             <description><![CDATA[
#                 앞으로는 대규모 재난 발생 시 호텔이나 리조트, 종교시설 등 민간 소유 시설도 시설 소유주와 협의가 되면 이재민을 위한 임시주거시설로 사용이 가능해집니다.<br /> <br />자세한 내용은 첨부를 확인하시기 바랍니다. <br /> <br />* 담당 : 재난구호과 이경자(044-205-5331)
#                     ]]></description>
#             <pubDate>MON, 03 FEB 2020 12:00:00 KST</pubDate>
#             <author>재난구호과</author>
#         </item>
#     <item>
#             <title><![CDATA[중국 우한 귀국 국민 임시생활시설 2곳 배치 완료]]></title>
#             <link><![CDATA[https://www.mois.go.kr/frt/bbs/type010/commonSelectBoardArticle.do?bbsId=BBSMSTR_000000000008&nttId=75583]]></link>
#             <description><![CDATA[
#                 정부는 1월 31일(금)과 2월 1일(토) 2차례에 걸쳐 중국 우한에서 전세기 편으로 귀국한 우리 국민 701명 전원을 안전하게 임시생활시설 2곳*에 배치 완료했습니다.<br /><br />자세한 내용은 첨부를 참고하시기 바랍니다. <br /><br />* 담당 : 사회재난대응정책과 양기현(044-205-5251)
#                     ]]></description>
#             <pubDate>SUN, 02 FEB 2020 16:30:00 KST</pubDate>
#             <author>사회재난대응정책과</author>
#         </item>
#     <item>
#             <title><![CDATA[신종 코로나바이러스 확산 방지에 지방재정 총력 대응]]></title>
#             <link><![CDATA[https://www.mois.go.kr/frt/bbs/type010/commonSelectBoardArticle.do?bbsId=BBSMSTR_000000000008&nttId=75576]]></link>
#             <description><![CDATA[
#                 행정안전부(장관 진영)는 지방자치단체와 함께 신종 코로나바이러스 감염증 확산 방지에 지방재정의 모든 수단을 강구하여 총력적으로 대응하기로 했습니다.<br /><br />자세한 내용은 첨부를 확인하시기 바랍니다. <br /> <br />* 담당 : 재정정책과 강민철(044-205-3706)
#                     ]]></description>
#             <pubDate>SUN, 02 FEB 2020 14:00:00 KST</pubDate>
#             <author>재정정책과</author>
#         </item>
#     <item>
#             <title><![CDATA[유선 및 도선 안전관리에 국민이 직접 참여한다]]></title>
#             <link><![CDATA[https://www.mois.go.kr/frt/bbs/type010/commonSelectBoardArticle.do?bbsId=BBSMSTR_000000000008&nttId=75575]]></link>
#             <description><![CDATA[
#                 행정안전부(장관 진영)는 일반 국민이 직접 유선 및 도선 안전관리에 참여하는 ‘제4기 유·도선 국민안전현장관찰단(현장관찰단)’을 2월 3일부터 28일까지 모집합니다.<br /><br />자세한 내용은 첨부를 확인하시기 바랍니다. <br /> <br />* 담당 : 안전제도과 우주형(044-205-4149)
#                     ]]></description>
#             <pubDate>SUN, 02 FEB 2020 12:00:00 KST</pubDate>
#             <author>안전제도과</author>
#         </item>
#     <item>
#             <title><![CDATA[취득세, 재산세 등 지방세 정책개선 주민과 함께 한다.]]></title>
#             <link><![CDATA[https://www.mois.go.kr/frt/bbs/type010/commonSelectBoardArticle.do?bbsId=BBSMSTR_000000000008&nttId=75574]]></link>
#             <description><![CDATA[
#                 행정안전부(장관 진영)는 2월 3일부터 29일까지 4주 동안 위택스(www.wetax.go.kr) 누리집에서 ｢2020년 지방세제 개편안｣ 마련을 위한 주민 아이디어를 공모합니다.<br /><br />자세한 내용은 첨부를 확인하시기 바랍니다. <br /> <br />* 담당 : 지방세정책과 김대철(044-205-3809)
#                     ]]></description>
#             <pubDate>SUN, 02 FEB 2020 12:00:00 KST</pubDate>
#             <author>지방세정책과</author>
#         </item>
#     <item>
#             <title><![CDATA[지방공기업 투자확대로 지역 경기부양 지원]]></title>
#             <link><![CDATA[https://www.mois.go.kr/frt/bbs/type010/commonSelectBoardArticle.do?bbsId=BBSMSTR_000000000008&nttId=75573]]></link>
#             <description><![CDATA[
#                 2020년 지방공기업은 주택공급, 노후관로 정비, 환경·안전 투자, 산업단지 조성 등 분야를 중심으로 확장적·포용적 지방재정 기조에 맞춰 투자를 확대할 계획입니다.<br /><br />자세한 내용은 첨부를 확인하시기 바랍니다. <br /> <br />* 담당 : 공기업정책과 백진걸(044-205-3963)
#                     ]]></description>
#             <pubDate>SUN, 02 FEB 2020 12:00:00 KST</pubDate>
#             <author>공기업정책과</author>
#         </item>
#     </channel>
# </rss>
#
#
# url : https://www.mois.go.kr/gpms/view/jsp/rss/rss.jsp?ctxCd=1013
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# <?xml version="1.0" encoding="UTF-8" ?>
# <rss version="2.0"
#     xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#     xmlns:dc="http://purl.org/dc/elements/1.1/"
#     xmlns:taxo="http://purl.org/rss/1.0/modules/taxonomy/"
#     xmlns:activity="http://activitystrea.ms/spec/1.0/" >
# <channel>
# <title>설명자료</title>
# <link>https://www.mois.go.kr</link>
# <description></description>
# <language>ko</language>
# <pubDate>TUE, 04 FEB 2020 15:13:41 KST</pubDate>
#     <item>
#             <title><![CDATA[(설명) 통 큰 양보했더니... 격리시설 주민에겐 마스크 지역 차별(채널A)]]></title>
#             <link><![CDATA[https://www.mois.go.kr/frt/bbs/type001/commonSelectBoardArticle.do?bbsId=BBSMSTR_000000000009&nttId=75615]]></link>
#             <description><![CDATA[
#                 지역주민 위생용품 보급 등을 위해 특별교부세 긴급 지원<br /><br />자세한 내용은 첨부를 확인하시기 바랍니다. <br /> <br />* 담당 : 사회재난대응정책과 양기현(044-205-5251)
#                     ]]></description>
#             <pubDate>TUE, 04 FEB 2020 15:13:41 KST</pubDate>
#             <author>사회재난대응정책과</author>
#         </item>
#     <item>
#             <title><![CDATA[(설명) 전염될까 걱정인데···세탁기 돌려쓰는 입소자들(채널A)]]></title>
#             <link><![CDATA[https://www.mois.go.kr/frt/bbs/type001/commonSelectBoardArticle.do?bbsId=BBSMSTR_000000000009&nttId=75614]]></link>
#             <description><![CDATA[
#                 임시생활시설 운영지침에 따라 철저히 운영 중<br /><br />자세한 내용은 첨부를 확인하시기 바랍니다. <br /> <br />* 담당 : 사회재난대응정책과 양기현(044-205-5251)
#                     ]]></description>
#             <pubDate>TUE, 04 FEB 2020 15:13:22 KST</pubDate>
#             <author>사회재난대응정책과</author>
#         </item>
#     </channel>
# </rss>

# %% [markdown]
# # 7. 주식 정보 가져오기
#
# 특정 사이트에서는 코드로 요청을 하는지 브라우져에서 요청을 하는지 구분을 하고 제한을 걸 수 있다.<br>
# 따라서 이러한 제한을 최소화하기 위해 코드로 직접 헤더정보를 입력하여 보내야 원하는 데이터를 수신할 수 있다.
#
#
# * 비동기 통신
#
# 처음에 랜더링될때는 원하는 없는 정보가 제공되고 추가적으로 후에 정보를 채워넣는 통신방식
#
# 따라서 요청했을 때 원하는 정보가 없을때는 구글 개발자도구의 네트워크탭에서 다른 url을 살펴본다.
#
# step1. preview 또는 response정보를 확인하여 원하는 정보가 있는지 본다. <br><br>
# step2. request Header 에서 브라우져로 인식시키기 위한 필요 정보를 확인한다.
# ex) referer:  , user-agent:<br>
#
# step3. fake-useragent 사용 , Header 정보삽입<br>
# pip install fake-useragent

# %%
import json  # 제공되는 데이터 타입이 json일때 사용

import urllib.request as req
from fake_useragent import UserAgent


# Fake Header정보 (가상으로 User-agent생성)
ua = UserAgent()
# print(ua.ie)
# print(ua.msie)
# print(ua.chrome)
# print(ua.safari)
# print(ua.random)


# 헤더 정보
headers = {
    'User-agent':ua.ie,
    'referer':'https://finance.daum.net/'
}


# 다음 주식 요청 URL
url = 'https://finance.daum.net/api/search/ranks?limit=10'


# 요청
res = req.urlopen( req.Request(url, headers=headers )).read().decode('UTF-8')


#응답 데이터 확인(Json Data)
# print('res',res)



#응답 데이터 str -> json 변환 및 data 값 출력
rank_json = json.loads(res)['data']


#중간확인
# print('중간확인:',rank_json,'\n')


for elm in rank_json:
    print('순위 : {}, 금액 : {}, 회사명 : {}'.format(elm['rank'],elm['tradePrice'],elm['name']))
    #파일(csv, 엑셀 , txt) 저장 및 db 저장
    #code
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-80-2010cd354c74> in <module>
#      31 #응답 데이터 확인(Json Data)
#      32 # print('res',res)
# ---> 33 print('headers: {}'.format(res.getheaders())) #수신된 헤더 정보
#      34
#      35
#
# AttributeError: 'str' object has no attribute 'getheaders'
